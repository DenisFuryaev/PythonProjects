# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = cv2.imread('image.jpg')
plt.imshow(image)
plt.imshow(cvtColor(image, cv2.BGR2RGB))
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-3d656158d073> in <module>
#       1 image = cv2.imread('image.jpg')
#       2 plt.imshow(image)
# ----> 3 plt.imshow(cvtColor(image, cv2.BGR2RGB))
#       4 #plt.show()
#
# NameError: name 'cvtColor' is not defined
